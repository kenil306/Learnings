# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Kenil Ramani\QB\GoalBot\CSV\dataset_v1.26.csv")
df4 = pd.read_csv(r"C:\Kenil Ramani\QB\GoalBot\CSV\dataset_v1.27.csv")
df2 = pd.read_csv(r"C:\Kenil Ramani\QB\neel\dataset\dataset_v1.24.csv")
df3 = pd.read_csv(r"C:\Kenil Ramani\QB\neel\dataset\dataset_v1.25.csv")

# %%
df
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 0        6/23/2023        2      6  2023            6            23
# 1        6/23/2023        2      6  2023            6            23
# 2        6/23/2023        2      6  2023            6            23
# 3         7/6/2022        3      7  2022            4             6
# 4         7/6/2022        3      7  2022            4             6
# ...            ...      ...    ...   ...          ...           ...
# 207641   4/15/2024        2      4  2024            2            15
# 207642    4/8/2024        2      4  2024            2             8
# 207643   11/4/2022        4     11  2022            6             4
# 207644   11/7/2022        4     11  2022            2             7
# 207645  11/12/2022        4     11  2022            7            12
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 0               174            25              195      140385  ...   1.0
# ...

# %%
df.isna().sum()
# Out:
# invoiceDate             0
# quarter                 0
# month                   0
# year                    0
# day_of_week             0
# day_of_month            0
# day_of_year             0
# week_of_year            0
# salesDetails_id         0
# billAmount              0
# stockistId          42557
# chemistId          165089
# hqId                    0
# regionId                0
# qty                     0
# free                    0
# rate                    0
# amount                  0
# productId               0
# divisionId              0
# mrp                     0
# packingTypeId           0
# dtype: int64

# %%
dff = df[(df['salesDetails_id']==564) & (df['productId']==42)]
print(dff.to_string())
# Out:
#      invoiceDate  quarter  month  year  day_of_week  day_of_month  day_of_year  week_of_year  salesDetails_id  billAmount  stockistId  chemistId  hqId  regionId  qty  free   rate  amount  productId  divisionId    mrp  packingTypeId
# 1505    7/1/2023        3      7  2023            7             1          182            26              564       52305       102.0        NaN  15.0       1.0   10     0  98.85   988.5       42.0         1.0  180.0           37.0
# 1506    7/1/2023        3      7  2023            7             1          182            26              564       52305       102.0        NaN  15.0       1.0   10     0  98.85   988.5       42.0         1.0  180.0           37.0

# %%
# df.drop_duplicates()

# %%
df_temp = df[df.duplicated()]
df_temp
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 1506      7/1/2023        3      7  2023            7             1
# 2026      7/7/2023        3      7  2023            6             7
# 2086      7/3/2023        3      7  2023            2             3
# 2108      7/4/2023        3      7  2023            3             4
# 4385     7/22/2023        3      7  2023            7            22
# ...            ...      ...    ...   ...          ...           ...
# 109263   6/18/2022        2      6  2022            7            18
# 110150   6/11/2024        2      6  2024            3            11
# 115627    5/4/2024        2      5  2024            7             4
# 121156    5/1/2023        2      5  2023            2             1
# 127886   5/17/2023        2      5  2023            4            17
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 1506            182            26              564       52305  ...  15.0
# ...

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 1506      7/1/2023        3      7  2023            7             1
# 2026      7/7/2023        3      7  2023            6             7
# 2086      7/3/2023        3      7  2023            2             3
# 2108      7/4/2023        3      7  2023            3             4
# 4385     7/22/2023        3      7  2023            7            22
# ...            ...      ...    ...   ...          ...           ...
# 109263   6/18/2022        2      6  2022            7            18
# 110150   6/11/2024        2      6  2024            3            11
# 115627    5/4/2024        2      5  2024            7             4
# 121156    5/1/2023        2      5  2023            2             1
# 127886   5/17/2023        2      5  2023            4            17
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 1506            182            26              564       52305  ...  15.0
# ...

# %%
df2
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 0        6/23/2023        2      6  2023            6            23
# 1        6/23/2023        2      6  2023            6            23
# 2        6/23/2023        2      6  2023            6            23
# 3         7/6/2022        3      7  2022            4             6
# 4         7/6/2022        3      7  2022            4             6
# ...            ...      ...    ...   ...          ...           ...
# 128949   11/6/2024        4     11  2024            4             6
# 128950   10/7/2024        4     10  2024            2             7
# 128951   10/7/2024        4     10  2024            2             7
# 128952   1/17/2025        1      1  2025            6            17
# 128953    3/3/2022        1      3  2022            5             3
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 0               174            25              195      140385  ...   1.0
# ...

# %%
df2_temp = df2[df2.duplicated()]
df2_temp
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 1619      7/1/2023        3      7  2023            7             1
# 2189      7/7/2023        3      7  2023            6             7
# 2270      7/3/2023        3      7  2023            2             3
# 2292      7/4/2023        3      7  2023            3             4
# 4628     7/22/2023        3      7  2023            7            22
# ...            ...      ...    ...   ...          ...           ...
# 110006  11/26/2024        4     11  2024            3            26
# 113320    7/1/2024        3      7  2024            2             1
# 118618   6/18/2022        2      6  2022            7            18
# 119564   6/11/2024        2      6  2024            3            11
# 125515    5/4/2024        2      5  2024            7             4
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 1619            182            26              564       52305  ...  15.0
# ...

# %%
df3_temp = df3[df3.duplicated()]
df3_temp
# Out:
# Empty DataFrame
# Columns: [invoiceDate, quarter, month, year, day_of_week, day_of_month, day_of_year, week_of_year, salesDetails_id, billAmount, stockistId, chemistId, hqId, regionId, qty, free, rate, amount, productId, divisionId, mrp, packingTypeId]
# Index: []
#
# [0 rows x 22 columns]

# %%
df4_temp = df4[df4.duplicated()]
df4_temp
# Out:
#        invoiceDate  quarter  month  year  day_of_week  day_of_month  \
# 1619      7/1/2023        3      7  2023            7             1
# 2189      7/7/2023        3      7  2023            6             7
# 2270      7/3/2023        3      7  2023            2             3
# 2292      7/4/2023        3      7  2023            3             4
# 4628     7/22/2023        3      7  2023            7            22
# ...            ...      ...    ...   ...          ...           ...
# 118618   6/18/2022        2      6  2022            7            18
# 119564   6/11/2024        2      6  2024            3            11
# 125515    5/4/2024        2      5  2024            7             4
# 131746    5/1/2023        2      5  2023            2             1
# 139003   5/17/2023        2      5  2023            4            17
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  hqId  \
# 1619            182            26              564       52305  ...  15.0
# ...
